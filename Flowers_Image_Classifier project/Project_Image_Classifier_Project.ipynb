# %% [markdown]
# # Your First AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) from Oxford of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load the image dataset and create a pipeline.
# * Build and Train an image classifier on this dataset.
# * Use your trained model to perform inference on flower images.
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.

# %% [markdown]
# ## Import Resources

# %%
# The new version of dataset is only available in the tfds-nightly package.
# %pip --no-cache-dir install tfds-nightly --user
# DON'T MISS TO RESTART THE KERNEL

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# TODO: Make all necessary imports.
import numpy as np
import pandas as pd
import requests
import json
from datetime import datetime
import tensorflow_hub as hub

from sklearn.utils import shuffle
from sklearn.preprocessing import LabelBinarizer
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
print('Using:')
print('\t\u2022 TensorFlow version:', tf.__version__)
print('\t\u2022 tf.keras version:', tf.keras.__version__)
print('\t\u2022 Running on GPU' if tf.test.is_gpu_available() else '\t\u2022 GPU device not found. Running on CPU')
# Out:
# Using:
# 	• TensorFlow version: 2.0.0
# 	• tf.keras version: 2.2.4-tf
# 	• GPU device not found. Running on CPU

# %% [markdown]
# ## Load the Dataset
#
# Here you'll use `tensorflow_datasets` to load the [Oxford Flowers 102 dataset](https://www.tensorflow.org/datasets/catalog/oxford_flowers102). This dataset has 3 splits: `'train'`, `'test'`, and `'validation'`.  You'll also need to make sure the training data is normalized and resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet, but you'll still need to normalize and resize the images to the appropriate size.

# %%
# Download data to default local directory "~/tensorflow_datasets"
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums=True --datasets=oxford_flowers102

# TODO: Load the dataset with TensorFlow Datasets.
dataset, dataset_info = tfds.load('oxford_flowers102', with_info=True, as_supervised=True)

# TODO: Create a training set, a validation set and a test set.
training_set, validation_set, test_set = dataset['train'], dataset['validation'], dataset['test']
# Out:
# I0604 17:48:08.067573 4621145536 download_and_prepare.py:171] Running download_and_prepare for datasets:
# oxford_flowers102
# I0604 17:48:08.068196 4621145536 download_and_prepare.py:172] Version: "None"
# W0604 17:48:08.068834 4621145536 dataset_builder.py:575] Found a different version 2.1.1 of dataset oxford_flowers102 in data_dir /Users/abdullahmohammed/tensorflow_datasets. Using currently defined version 0.0.1.
# I0604 17:48:08.068923 4621145536 dataset_builder.py:187] Load pre-computed datasetinfo (eg: splits) from bucket.
# I0604 17:48:08.912966 4621145536 dataset_info.py:410] Loading info from GCS for oxford_flowers102/0.0.1
# I0604 17:48:11.039200 4621145536 download_and_prepare.py:122] download_and_prepare for dataset oxford_flowers102/0.0.1...
# I0604 17:48:11.718163 4621145536 dataset_builder.py:273] Generating dataset oxford_flowers102 (/Users/abdullahmohammed/tensorflow_datasets/oxford_flowers102/0.0.1)
# Downloading and preparing dataset oxford_flowers102 (336.76 MiB) to /Users/abdullahmohammed/tensorflow_datasets/oxford_flowers102/0.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0604 17:48:11.722301 4621145536 download_manager.py:241] Downloading https://www.robots.ox.ac.uk/~vgg/data/flowers/102/102flowers.tgz into /Users/abdullahmohammed/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_102flowersoWedSp98maBn1wypsDib6T-q2NVbO40fwvTflmPmQpY.tgz.tmp.c909a299a065450893044220bc523dd6...
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]I0604 17:48:11.724183 4621145536 download_manager.py:231] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/imagelabels.mat already downloaded: reusing /Users/abdullahmohammed/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat.
# I0604 17:48:11.724852 4621145536 download_manager.py:258] Skipping extraction for /Users/abdullahmohammed/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_imagelabelSQPpQga6wjv3cqrfBkUZFt9WtY_Eg6YtsyqXuCZWZR0.mat (method=NO_EXTRACT).
# I0604 17:48:11.725203 4621145536 download_manager.py:231] URL https://www.robots.ox.ac.uk/~vgg/data/flowers/102/setid.mat already downloaded: reusing /Users/abdullahmohammed/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat.
# I0604 17:48:11.725773 4621145536 download_manager.py:258] Skipping extraction for /Users/abdullahmohammed/tensorflow_datasets/downloads/robots.ox.ac.uk_vgg_flowers_102_setidRrhnj5H9ldPI9P6rgNJxpsg0od2Jb-Kf0-atnOXI3M0.mat (method=NO_EXTRACT).
# /Users/abdullahmohammed/anaconda3/envs/new/lib/python3.6/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.robots.ox.ac.uk'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# Dl Completed...:   0%|                                  | 0/1 [00:00<?, ? url/s]
# Dl Size...:   0%|                                     | 0/328 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:02<?, ? url/s]
# Dl Size...:   0%|                             | 1/328 [00:02<16:09,  2.97s/ MiB]
#
# Extraction completed...: 0 file [00:02, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:04<?, ? url/s]
# Dl Size...:   1%|1                            | 2/328 [00:04<13:27,  2.48s/ MiB]
#
# Extraction completed...: 0 file [00:04, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:   1%|2                            | 3/328 [00:05<10:54,  2.01s/ MiB]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:05<?, ? url/s]
# Dl Size...:   1%|3                            | 4/328 [00:05<08:45,  1.62s/ MiB]
#
# Extraction completed...: 0 file [00:05, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:06<?, ? url/s]
# Dl Size...:   2%|4                            | 5/328 [00:06<06:54,  1.28s/ MiB]
#
# Extraction completed...: 0 file [00:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:06<?, ? url/s]
# Dl Size...:   2%|5                            | 6/328 [00:06<05:37,  1.05s/ MiB]
#
# Extraction completed...: 0 file [00:06, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:07<?, ? url/s]
# Dl Size...:   2%|6                            | 7/328 [00:07<05:12,  1.03 MiB/s]
#
# Extraction completed...: 0 file [00:07, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:   2%|7                            | 8/328 [00:08<04:12,  1.27 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:08<?, ? url/s]
# Dl Size...:   3%|7                            | 9/328 [00:08<03:35,  1.48 MiB/s]
#
# Extraction completed...: 0 file [00:08, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:   3%|8                           | 10/328 [00:09<03:20,  1.58 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:09<?, ? url/s]
# Dl Size...:   3%|9                           | 11/328 [00:09<03:12,  1.64 MiB/s]
#
# Extraction completed...: 0 file [00:09, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:10<?, ? url/s]
# Dl Size...:   4%|#                           | 12/328 [00:10<03:31,  1.50 MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:10<?, ? url/s]
# Dl Size...:   4%|#1                          | 13/328 [00:10<03:14,  1.62 MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:11<?, ? url/s]
# Dl Size...:   4%|#1                          | 14/328 [00:11<03:03,  1.71 MiB/s]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:12<?, ? url/s]
# Dl Size...:   5%|#2                          | 15/328 [00:12<03:15,  1.60 MiB/s]
#
# Extraction completed...: 0 file [00:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:12<?, ? url/s]
# Dl Size...:   5%|#3                          | 16/328 [00:12<03:17,  1.58 MiB/s]
#
# Extraction completed...: 0 file [00:12, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:13<?, ? url/s]
# Dl Size...:   5%|#4                          | 17/328 [00:13<03:29,  1.49 MiB/s]
#
# Extraction completed...: 0 file [00:13, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:14<?, ? url/s]
# Dl Size...:   5%|#5                          | 18/328 [00:14<03:31,  1.47 MiB/s]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:14<?, ? url/s]
# Dl Size...:   6%|#6                          | 19/328 [00:14<03:17,  1.56 MiB/s]
#
# Extraction completed...: 0 file [00:14, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:15<?, ? url/s]
# Dl Size...:   6%|#7                          | 20/328 [00:15<03:09,  1.62 MiB/s]
#
# Extraction completed...: 0 file [00:15, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:16<?, ? url/s]
# Dl Size...:   6%|#7                          | 21/328 [00:16<03:16,  1.56 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:16<?, ? url/s]
# Dl Size...:   7%|#8                          | 22/328 [00:16<02:53,  1.76 MiB/s]
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:16<?, ? url/s]
# Dl Size...:   7%|#9                          | 23/328 [00:16<02:34,  1.97 MiB/s]
#
# Extraction completed...: 0 file [00:16, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:17<?, ? url/s]
# Dl Size...:   7%|##                          | 24/328 [00:17<02:19,  2.17 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:17<?, ? url/s]
# Dl Size...:   8%|##1                         | 25/328 [00:17<02:10,  2.33 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:17<?, ? url/s]
# Dl Size...:   8%|##2                         | 26/328 [00:17<02:08,  2.36 MiB/s]
#
# Extraction completed...: 0 file [00:17, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:18<?, ? url/s]
# Dl Size...:   8%|##3                         | 27/328 [00:18<01:57,  2.57 MiB/s]
#
# Extraction completed...: 0 file [00:18, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:18<?, ? url/s]
# Dl Size...:   9%|##3                         | 28/328 [00:18<02:02,  2.45 MiB/s]
#
# Extraction completed...: 0 file [00:18, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:19<?, ? url/s]
# Dl Size...:   9%|##4                         | 29/328 [00:19<02:06,  2.37 MiB/s]
#
# Extraction completed...: 0 file [00:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:19<?, ? url/s]
# Dl Size...:   9%|##5                         | 30/328 [00:19<02:03,  2.41 MiB/s]
#
# Extraction completed...: 0 file [00:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:19<?, ? url/s]
# Dl Size...:   9%|##6                         | 31/328 [00:19<01:54,  2.60 MiB/s]
#
# Extraction completed...: 0 file [00:19, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:20<?, ? url/s]
# Dl Size...:  10%|##7                         | 32/328 [00:20<01:45,  2.81 MiB/s]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:20<?, ? url/s]
# Dl Size...:  10%|##8                         | 33/328 [00:20<01:37,  3.01 MiB/s]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:20<?, ? url/s]
# Dl Size...:  10%|##9                         | 34/328 [00:20<01:41,  2.91 MiB/s]
#
# Extraction completed...: 0 file [00:20, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:21<?, ? url/s]
# Dl Size...:  11%|##9                         | 35/328 [00:21<01:36,  3.04 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:21<?, ? url/s]
# Dl Size...:  11%|###                         | 36/328 [00:21<01:37,  2.99 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:21<?, ? url/s]
# Dl Size...:  11%|###1                        | 37/328 [00:21<01:31,  3.18 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:21<?, ? url/s]
# Dl Size...:  12%|###2                        | 38/328 [00:21<01:26,  3.34 MiB/s]
#
# Extraction completed...: 0 file [00:21, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:22<?, ? url/s]
# Dl Size...:  12%|###3                        | 39/328 [00:22<01:23,  3.45 MiB/s]
#
# Extraction completed...: 0 file [00:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:22<?, ? url/s]
# Dl Size...:  12%|###4                        | 40/328 [00:22<01:30,  3.18 MiB/s]
#
# Extraction completed...: 0 file [00:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:22<?, ? url/s]
# Dl Size...:  12%|###5                        | 41/328 [00:22<01:28,  3.26 MiB/s]
#
# Extraction completed...: 0 file [00:22, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:23<?, ? url/s]
# Dl Size...:  13%|###5                        | 42/328 [00:23<01:25,  3.33 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:23<?, ? url/s]
# Dl Size...:  13%|###6                        | 43/328 [00:23<01:30,  3.13 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:23<?, ? url/s]
# Dl Size...:  13%|###7                        | 44/328 [00:23<01:26,  3.28 MiB/s]
#
# Extraction completed...: 0 file [00:23, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:24<?, ? url/s]
# Dl Size...:  14%|###8                        | 45/328 [00:24<01:24,  3.34 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:24<?, ? url/s]
# Dl Size...:  14%|###9                        | 46/328 [00:24<01:24,  3.36 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:24<?, ? url/s]
# Dl Size...:  14%|####                        | 47/328 [00:24<01:22,  3.39 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:24<?, ? url/s]
# Dl Size...:  15%|####                        | 48/328 [00:24<01:22,  3.40 MiB/s]
#
# Extraction completed...: 0 file [00:24, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:25<?, ? url/s]
# Dl Size...:  15%|####1                       | 49/328 [00:25<01:19,  3.49 MiB/s]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:25<?, ? url/s]
# Dl Size...:  15%|####2                       | 50/328 [00:25<01:16,  3.63 MiB/s]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:25<?, ? url/s]
# Dl Size...:  16%|####3                       | 51/328 [00:25<01:21,  3.38 MiB/s]
#
# Extraction completed...: 0 file [00:25, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:26<?, ? url/s]
# Dl Size...:  16%|####4                       | 52/328 [00:26<01:22,  3.35 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:26<?, ? url/s]
# Dl Size...:  16%|####5                       | 53/328 [00:26<01:16,  3.58 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:26<?, ? url/s]
# Dl Size...:  16%|####6                       | 54/328 [00:26<01:20,  3.41 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:26<?, ? url/s]
# Dl Size...:  17%|####6                       | 55/328 [00:26<01:18,  3.48 MiB/s]
#
# Extraction completed...: 0 file [00:26, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:27<?, ? url/s]
# Dl Size...:  17%|####7                       | 56/328 [00:27<01:23,  3.26 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:27<?, ? url/s]
# Dl Size...:  17%|####8                       | 57/328 [00:27<01:24,  3.21 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:27<?, ? url/s]
# Dl Size...:  18%|####9                       | 58/328 [00:27<01:18,  3.42 MiB/s]
#
# Extraction completed...: 0 file [00:27, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:28<?, ? url/s]
# Dl Size...:  18%|#####                       | 59/328 [00:28<01:19,  3.40 MiB/s]
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:28<?, ? url/s]
# Dl Size...:  18%|#####1                      | 60/328 [00:28<01:20,  3.32 MiB/s]
#
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:28<?, ? url/s]
# Dl Size...:  19%|#####2                      | 61/328 [00:28<01:19,  3.38 MiB/s]
#
# Extraction completed...: 0 file [00:28, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:29<?, ? url/s]
# Dl Size...:  19%|#####2                      | 62/328 [00:29<01:18,  3.37 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:29<?, ? url/s]
# Dl Size...:  19%|#####3                      | 63/328 [00:29<01:18,  3.38 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:29<?, ? url/s]
# Dl Size...:  20%|#####4                      | 64/328 [00:29<01:13,  3.61 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:29<?, ? url/s]
# Dl Size...:  20%|#####5                      | 65/328 [00:29<01:16,  3.45 MiB/s]
#
# Extraction completed...: 0 file [00:29, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:30<?, ? url/s]
# Dl Size...:  20%|#####6                      | 66/328 [00:30<01:13,  3.56 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:30<?, ? url/s]
# Dl Size...:  20%|#####7                      | 67/328 [00:30<01:08,  3.83 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:30<?, ? url/s]
# Dl Size...:  21%|#####8                      | 68/328 [00:30<01:09,  3.76 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:30<?, ? url/s]
# Dl Size...:  21%|#####8                      | 69/328 [00:30<01:07,  3.83 MiB/s]
#
# Extraction completed...: 0 file [00:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:  21%|#####9                      | 70/328 [00:31<01:05,  3.92 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:  22%|######                      | 71/328 [00:31<01:02,  4.09 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:  22%|######1                     | 72/328 [00:31<01:05,  3.90 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:31<?, ? url/s]
# Dl Size...:  22%|######2                     | 73/328 [00:31<01:05,  3.89 MiB/s]
#
# Extraction completed...: 0 file [00:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:  23%|######3                     | 74/328 [00:32<01:03,  3.98 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:  23%|######4                     | 75/328 [00:32<01:03,  4.01 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:  23%|######4                     | 76/328 [00:32<00:59,  4.25 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:32<?, ? url/s]
# Dl Size...:  23%|######5                     | 77/328 [00:32<01:00,  4.15 MiB/s]
#
# Extraction completed...: 0 file [00:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:33<?, ? url/s]
# Dl Size...:  24%|######6                     | 78/328 [00:33<00:55,  4.52 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:33<?, ? url/s]
# Dl Size...:  24%|######7                     | 79/328 [00:33<00:55,  4.52 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:33<?, ? url/s]
# Dl Size...:  24%|######8                     | 80/328 [00:33<00:55,  4.48 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:33<?, ? url/s]
# Dl Size...:  25%|######9                     | 81/328 [00:33<00:52,  4.66 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:33<?, ? url/s]
# Dl Size...:  25%|#######                     | 82/328 [00:33<00:52,  4.73 MiB/s]
#
# Extraction completed...: 0 file [00:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:  25%|#######                     | 83/328 [00:34<00:51,  4.80 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:  26%|#######1                    | 84/328 [00:34<00:49,  4.88 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:  26%|#######2                    | 85/328 [00:34<00:51,  4.76 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:  26%|#######3                    | 86/328 [00:34<00:51,  4.74 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:34<?, ? url/s]
# Dl Size...:  27%|#######4                    | 87/328 [00:34<00:48,  5.01 MiB/s]
#
# Extraction completed...: 0 file [00:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  27%|#######5                    | 88/328 [00:35<00:49,  4.88 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  27%|#######5                    | 89/328 [00:35<00:46,  5.14 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  27%|#######6                    | 90/328 [00:35<00:43,  5.53 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  28%|#######7                    | 91/328 [00:35<00:48,  4.89 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:35<?, ? url/s]
# Dl Size...:  28%|#######8                    | 92/328 [00:35<00:43,  5.37 MiB/s]
#
# Extraction completed...: 0 file [00:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  28%|#######9                    | 93/328 [00:36<00:42,  5.54 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  29%|########                    | 94/328 [00:36<00:46,  5.06 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  29%|########1                   | 95/328 [00:36<00:42,  5.51 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  29%|########1                   | 96/328 [00:36<00:39,  5.94 MiB/s]
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  30%|########2                   | 97/328 [00:36<00:39,  5.81 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:36<?, ? url/s]
# Dl Size...:  30%|########3                   | 98/328 [00:36<00:40,  5.62 MiB/s]
#
# Extraction completed...: 0 file [00:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  30%|########4                   | 99/328 [00:37<00:38,  5.97 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  30%|########2                  | 100/328 [00:37<00:37,  6.06 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  31%|########3                  | 101/328 [00:37<00:34,  6.54 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  31%|########3                  | 102/328 [00:37<00:34,  6.47 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  31%|########4                  | 103/328 [00:37<00:33,  6.74 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  32%|########5                  | 104/328 [00:37<00:35,  6.32 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:37<?, ? url/s]
# Dl Size...:  32%|########6                  | 105/328 [00:37<00:32,  6.76 MiB/s]
#
# Extraction completed...: 0 file [00:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  32%|########7                  | 106/328 [00:38<00:31,  7.16 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  33%|########8                  | 107/328 [00:38<00:34,  6.37 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  33%|########8                  | 108/328 [00:38<00:34,  6.37 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  33%|########9                  | 109/328 [00:38<00:34,  6.38 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  34%|#########                  | 110/328 [00:38<00:34,  6.23 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:38<?, ? url/s]
# Dl Size...:  34%|#########1                 | 111/328 [00:38<00:35,  6.12 MiB/s]
#
# Extraction completed...: 0 file [00:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  34%|#########2                 | 112/328 [00:39<00:36,  5.95 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  34%|#########3                 | 113/328 [00:39<00:34,  6.25 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  35%|#########3                 | 114/328 [00:39<00:34,  6.25 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  35%|#########4                 | 115/328 [00:39<00:31,  6.76 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  35%|#########5                 | 116/328 [00:39<00:32,  6.54 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  36%|#########6                 | 117/328 [00:39<00:31,  6.69 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:39<?, ? url/s]
# Dl Size...:  36%|#########7                 | 118/328 [00:39<00:31,  6.76 MiB/s]
#
# Extraction completed...: 0 file [00:39, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:40<?, ? url/s]
# Dl Size...:  36%|#########7                 | 119/328 [00:40<00:29,  7.17 MiB/s]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:40<?, ? url/s]
# Dl Size...:  37%|#########8                 | 120/328 [00:40<00:35,  5.83 MiB/s]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:40<?, ? url/s]
# Dl Size...:  37%|#########9                 | 121/328 [00:40<00:47,  4.32 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:40<?, ? url/s]
# Dl Size...:  37%|##########                 | 122/328 [00:40<00:47,  4.32 MiB/s]
#
# Extraction completed...: 0 file [00:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:41<?, ? url/s]
# Dl Size...:  38%|##########1                | 123/328 [00:41<00:51,  3.94 MiB/s]
#
# Extraction completed...: 0 file [00:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:41<?, ? url/s]
# Dl Size...:  38%|##########2                | 124/328 [00:41<00:49,  4.14 MiB/s]
#
# Extraction completed...: 0 file [00:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:41<?, ? url/s]
# Dl Size...:  38%|##########2                | 125/328 [00:41<00:52,  3.86 MiB/s]
#
# Extraction completed...: 0 file [00:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:41<?, ? url/s]
# Dl Size...:  38%|##########3                | 126/328 [00:41<00:45,  4.40 MiB/s]
#
# Extraction completed...: 0 file [00:41, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:42<?, ? url/s]
# Dl Size...:  39%|##########4                | 127/328 [00:42<00:53,  3.75 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:42<?, ? url/s]
# Dl Size...:  39%|##########5                | 128/328 [00:42<00:53,  3.75 MiB/s]
#
# Extraction completed...: 0 file [00:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:42<?, ? url/s]
# Dl Size...:  39%|##########6                | 129/328 [00:42<00:50,  3.96 MiB/s]
#
# Extraction completed...: 0 file [00:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  40%|##########7                | 130/328 [00:43<00:53,  3.69 MiB/s]
#
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  40%|##########7                | 131/328 [00:43<00:43,  4.54 MiB/s]
#
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  40%|##########8                | 132/328 [00:43<00:46,  4.18 MiB/s]
#
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  41%|##########9                | 133/328 [00:43<00:43,  4.50 MiB/s]
#
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  41%|###########                | 134/328 [00:43<00:36,  5.34 MiB/s]
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:43<?, ? url/s]
# Dl Size...:  41%|###########1               | 135/328 [00:43<00:34,  5.59 MiB/s]
#
# Extraction completed...: 0 file [00:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  41%|###########1               | 136/328 [00:44<00:37,  5.14 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  42%|###########2               | 137/328 [00:44<00:37,  5.14 MiB/s]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  42%|###########3               | 138/328 [00:44<00:37,  5.11 MiB/s]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  42%|###########4               | 139/328 [00:44<00:33,  5.58 MiB/s]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  43%|###########5               | 140/328 [00:44<00:34,  5.37 MiB/s]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:44<?, ? url/s]
# Dl Size...:  43%|###########6               | 141/328 [00:44<00:31,  5.87 MiB/s]
#
# Extraction completed...: 0 file [00:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:45<?, ? url/s]
# Dl Size...:  43%|###########6               | 142/328 [00:45<00:32,  5.70 MiB/s]
#
# Extraction completed...: 0 file [00:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:45<?, ? url/s]
# Dl Size...:  44%|###########7               | 143/328 [00:45<00:33,  5.48 MiB/s]
#
# Extraction completed...: 0 file [00:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:45<?, ? url/s]
# Dl Size...:  44%|###########8               | 144/328 [00:45<00:29,  6.21 MiB/s]
#
# Extraction completed...: 0 file [00:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:45<?, ? url/s]
# Dl Size...:  44%|###########9               | 145/328 [00:45<00:31,  5.85 MiB/s]
#
# Extraction completed...: 0 file [00:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:45<?, ? url/s]
# Dl Size...:  45%|############               | 146/328 [00:45<00:31,  5.79 MiB/s]
#
# Extraction completed...: 0 file [00:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  45%|############1              | 147/328 [00:46<00:30,  5.94 MiB/s]
#
# Extraction completed...: 0 file [00:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  45%|############1              | 148/328 [00:46<00:28,  6.41 MiB/s]
#
# Extraction completed...: 0 file [00:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  45%|############2              | 149/328 [00:46<00:30,  5.79 MiB/s]
#
# Extraction completed...: 0 file [00:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  46%|############3              | 150/328 [00:46<00:40,  4.43 MiB/s]
#
# Dl Completed...:   0%|                                  | 0/1 [00:46<?, ? url/s]
# Dl Size...:  46%|############4              | 151/328 [00:46<00:39,  4.43 MiB/s]
#
# Extraction completed...: 0 file [00:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:47<?, ? url/s]
# Dl Size...:  46%|############5              | 152/328 [00:47<00:40,  4.37 MiB/s]
#
# Extraction completed...: 0 file [00:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:47<?, ? url/s]
# Dl Size...:  47%|############5              | 153/328 [00:47<00:41,  4.20 MiB/s]
#
# Extraction completed...: 0 file [00:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:47<?, ? url/s]
# Dl Size...:  47%|############6              | 154/328 [00:47<00:37,  4.68 MiB/s]
#
# Extraction completed...: 0 file [00:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:47<?, ? url/s]
# Dl Size...:  47%|############7              | 155/328 [00:47<00:35,  4.94 MiB/s]
#
# Extraction completed...: 0 file [00:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:47<?, ? url/s]
# Dl Size...:  48%|############8              | 156/328 [00:47<00:34,  4.95 MiB/s]
#
# Extraction completed...: 0 file [00:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:48<?, ? url/s]
# Dl Size...:  48%|############9              | 157/328 [00:48<00:31,  5.37 MiB/s]
#
# Extraction completed...: 0 file [00:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:48<?, ? url/s]
# Dl Size...:  48%|#############              | 158/328 [00:48<00:31,  5.37 MiB/s]
#
# Extraction completed...: 0 file [00:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:48<?, ? url/s]
# Dl Size...:  48%|#############              | 159/328 [00:48<00:33,  5.04 MiB/s]
#
# Extraction completed...: 0 file [00:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:48<?, ? url/s]
# Dl Size...:  49%|#############1             | 160/328 [00:48<00:34,  4.82 MiB/s]
#
# Extraction completed...: 0 file [00:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:48<?, ? url/s]
# Dl Size...:  49%|#############2             | 161/328 [00:48<00:33,  4.93 MiB/s]
#
# Extraction completed...: 0 file [00:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  49%|#############3             | 162/328 [00:49<00:35,  4.63 MiB/s]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  50%|#############4             | 163/328 [00:49<00:32,  5.04 MiB/s]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  50%|#############5             | 164/328 [00:49<00:31,  5.26 MiB/s]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  50%|#############5             | 165/328 [00:49<00:29,  5.55 MiB/s]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:49<?, ? url/s]
# Dl Size...:  51%|#############6             | 166/328 [00:49<00:31,  5.20 MiB/s]
#
# Extraction completed...: 0 file [00:49, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  51%|#############7             | 167/328 [00:50<00:27,  5.75 MiB/s]
#
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  51%|#############8             | 168/328 [00:50<00:29,  5.38 MiB/s]
#
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  52%|#############9             | 169/328 [00:50<00:28,  5.62 MiB/s]
#
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  52%|#############9             | 170/328 [00:50<00:26,  5.99 MiB/s]
#
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  52%|##############             | 171/328 [00:50<00:25,  6.07 MiB/s]
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:50<?, ? url/s]
# Dl Size...:  52%|##############1            | 172/328 [00:50<00:32,  4.85 MiB/s]
#
# Extraction completed...: 0 file [00:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  53%|##############2            | 173/328 [00:51<00:30,  5.13 MiB/s]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  53%|##############3            | 174/328 [00:51<00:28,  5.42 MiB/s]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  53%|##############4            | 175/328 [00:51<00:28,  5.36 MiB/s]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  54%|##############4            | 176/328 [00:51<00:29,  5.22 MiB/s]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:51<?, ? url/s]
# Dl Size...:  54%|##############5            | 177/328 [00:51<00:26,  5.70 MiB/s]
#
# Extraction completed...: 0 file [00:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:52<?, ? url/s]
# Dl Size...:  54%|##############6            | 178/328 [00:52<00:25,  5.80 MiB/s]
#
# Extraction completed...: 0 file [00:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:52<?, ? url/s]
# Dl Size...:  55%|##############7            | 179/328 [00:52<00:24,  6.11 MiB/s]
#
# Extraction completed...: 0 file [00:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:52<?, ? url/s]
# Dl Size...:  55%|##############8            | 180/328 [00:52<00:25,  5.82 MiB/s]
#
# Extraction completed...: 0 file [00:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:52<?, ? url/s]
# Dl Size...:  55%|##############8            | 181/328 [00:52<00:31,  4.71 MiB/s]
#
# Extraction completed...: 0 file [00:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:52<?, ? url/s]
# Dl Size...:  55%|##############9            | 182/328 [00:52<00:30,  4.75 MiB/s]
#
# Extraction completed...: 0 file [00:52, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  56%|###############            | 183/328 [00:53<00:32,  4.42 MiB/s]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  56%|###############1           | 184/328 [00:53<00:32,  4.43 MiB/s]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  56%|###############2           | 185/328 [00:53<00:32,  4.36 MiB/s]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  57%|###############3           | 186/328 [00:53<00:31,  4.56 MiB/s]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:53<?, ? url/s]
# Dl Size...:  57%|###############3           | 187/328 [00:53<00:29,  4.74 MiB/s]
#
# Extraction completed...: 0 file [00:53, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:54<?, ? url/s]
# Dl Size...:  57%|###############4           | 188/328 [00:54<00:31,  4.45 MiB/s]
#
# Extraction completed...: 0 file [00:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:54<?, ? url/s]
# Dl Size...:  58%|###############5           | 189/328 [00:54<00:28,  4.86 MiB/s]
#
# Extraction completed...: 0 file [00:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:54<?, ? url/s]
# Dl Size...:  58%|###############6           | 190/328 [00:54<00:25,  5.32 MiB/s]
#
# Extraction completed...: 0 file [00:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:54<?, ? url/s]
# Dl Size...:  58%|###############7           | 191/328 [00:54<00:24,  5.62 MiB/s]
#
# Extraction completed...: 0 file [00:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:54<?, ? url/s]
# Dl Size...:  59%|###############8           | 192/328 [00:54<00:25,  5.23 MiB/s]
#
# Extraction completed...: 0 file [00:54, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  59%|###############8           | 193/328 [00:55<00:24,  5.40 MiB/s]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  59%|###############9           | 194/328 [00:55<00:25,  5.22 MiB/s]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  59%|################           | 195/328 [00:55<00:23,  5.57 MiB/s]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  60%|################1          | 196/328 [00:55<00:22,  5.74 MiB/s]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:55<?, ? url/s]
# Dl Size...:  60%|################2          | 197/328 [00:55<00:23,  5.61 MiB/s]
#
# Extraction completed...: 0 file [00:55, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:56<?, ? url/s]
# Dl Size...:  60%|################2          | 198/328 [00:56<00:26,  4.91 MiB/s]
#
# Extraction completed...: 0 file [00:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:56<?, ? url/s]
# Dl Size...:  61%|################3          | 199/328 [00:56<00:27,  4.70 MiB/s]
#
# Extraction completed...: 0 file [00:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:56<?, ? url/s]
# Dl Size...:  61%|################4          | 200/328 [00:56<00:27,  4.73 MiB/s]
#
# Extraction completed...: 0 file [00:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:56<?, ? url/s]
# Dl Size...:  61%|################5          | 201/328 [00:56<00:25,  4.91 MiB/s]
#
# Extraction completed...: 0 file [00:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:56<?, ? url/s]
# Dl Size...:  62%|################6          | 202/328 [00:56<00:24,  5.07 MiB/s]
#
# Extraction completed...: 0 file [00:56, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  62%|################7          | 203/328 [00:57<00:27,  4.55 MiB/s]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  62%|################7          | 204/328 [00:57<00:27,  4.53 MiB/s]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  62%|################8          | 205/328 [00:57<00:26,  4.59 MiB/s]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  63%|################9          | 206/328 [00:57<00:25,  4.82 MiB/s]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:57<?, ? url/s]
# Dl Size...:  63%|#################          | 207/328 [00:57<00:23,  5.05 MiB/s]
#
# Extraction completed...: 0 file [00:57, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:58<?, ? url/s]
# Dl Size...:  63%|#################1         | 208/328 [00:58<00:28,  4.24 MiB/s]
# Extraction completed...: 0 file [00:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:58<?, ? url/s]
# Dl Size...:  64%|#################2         | 209/328 [00:58<00:28,  4.18 MiB/s]
#
# Extraction completed...: 0 file [00:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:58<?, ? url/s]
# Dl Size...:  64%|#################2         | 210/328 [00:58<00:30,  3.90 MiB/s]
#
# Extraction completed...: 0 file [00:58, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [00:59<?, ? url/s]
# Dl Size...:  64%|#################3         | 211/328 [00:59<00:29,  4.01 MiB/s]
#
# Extraction completed...: 0 file [00:59, ? file/s]
# ...
# Dl Size...:  88%|#######################7   | 289/328 [01:30<00:18,  2.11 MiB/s]
#
# Extraction completed...: 0 file [01:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:30<?, ? url/s]
# Dl Size...:  88%|#######################8   | 290/328 [01:30<00:17,  2.15 MiB/s]
#
# Extraction completed...: 0 file [01:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:30<?, ? url/s]
# Dl Size...:  89%|#######################9   | 291/328 [01:30<00:17,  2.13 MiB/s]
#
# Extraction completed...: 0 file [01:30, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:31<?, ? url/s]
# Dl Size...:  89%|########################   | 292/328 [01:31<00:16,  2.19 MiB/s]
#
# Extraction completed...: 0 file [01:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:31<?, ? url/s]
# Dl Size...:  89%|########################1  | 293/328 [01:31<00:16,  2.08 MiB/s]
#
# Extraction completed...: 0 file [01:31, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:32<?, ? url/s]
# Dl Size...:  90%|########################2  | 294/328 [01:32<00:16,  2.08 MiB/s]
#
# Extraction completed...: 0 file [01:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:32<?, ? url/s]
# Dl Size...:  90%|########################2  | 295/328 [01:32<00:16,  2.01 MiB/s]
#
# Extraction completed...: 0 file [01:32, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:33<?, ? url/s]
# Dl Size...:  90%|########################3  | 296/328 [01:33<00:15,  2.12 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:33<?, ? url/s]
# Dl Size...:  91%|########################4  | 297/328 [01:33<00:13,  2.22 MiB/s]
#
# Extraction completed...: 0 file [01:33, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:34<?, ? url/s]
# Dl Size...:  91%|########################5  | 298/328 [01:34<00:13,  2.21 MiB/s]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:34<?, ? url/s]
# Dl Size...:  91%|########################6  | 299/328 [01:34<00:13,  2.18 MiB/s]
#
# Extraction completed...: 0 file [01:34, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:35<?, ? url/s]
# Dl Size...:  91%|########################6  | 300/328 [01:35<00:12,  2.19 MiB/s]
#
# Extraction completed...: 0 file [01:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:35<?, ? url/s]
# Dl Size...:  92%|########################7  | 301/328 [01:35<00:11,  2.27 MiB/s]
#
# Extraction completed...: 0 file [01:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:35<?, ? url/s]
# Dl Size...:  92%|########################8  | 302/328 [01:35<00:11,  2.33 MiB/s]
#
# Extraction completed...: 0 file [01:35, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:36<?, ? url/s]
# Dl Size...:  92%|########################9  | 303/328 [01:36<00:10,  2.34 MiB/s]
#
# Extraction completed...: 0 file [01:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:36<?, ? url/s]
# Dl Size...:  93%|#########################  | 304/328 [01:36<00:10,  2.31 MiB/s]
#
# Extraction completed...: 0 file [01:36, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:37<?, ? url/s]
# Dl Size...:  93%|#########################1 | 305/328 [01:37<00:10,  2.19 MiB/s]
#
# Extraction completed...: 0 file [01:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:37<?, ? url/s]
# Dl Size...:  93%|#########################1 | 306/328 [01:37<00:09,  2.26 MiB/s]
#
# Extraction completed...: 0 file [01:37, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:38<?, ? url/s]
# Dl Size...:  94%|#########################2 | 307/328 [01:38<00:09,  2.12 MiB/s]
#
# Extraction completed...: 0 file [01:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:38<?, ? url/s]
# Dl Size...:  94%|#########################3 | 308/328 [01:38<00:09,  2.02 MiB/s]
#
# Extraction completed...: 0 file [01:38, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:40<?, ? url/s]
# Dl Size...:  94%|#########################4 | 309/328 [01:40<00:15,  1.20 MiB/s]
#
# Extraction completed...: 0 file [01:40, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:42<?, ? url/s]
# Dl Size...:  95%|#########################5 | 310/328 [01:42<00:20,  1.12s/ MiB]
#
# Extraction completed...: 0 file [01:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:42<?, ? url/s]
# Dl Size...:  95%|#########################6 | 311/328 [01:42<00:16,  1.06 MiB/s]
#
# Extraction completed...: 0 file [01:42, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:43<?, ? url/s]
# Dl Size...:  95%|#########################6 | 312/328 [01:43<00:12,  1.30 MiB/s]
#
# Extraction completed...: 0 file [01:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:43<?, ? url/s]
# Dl Size...:  95%|#########################7 | 313/328 [01:43<00:09,  1.53 MiB/s]
#
# Extraction completed...: 0 file [01:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:43<?, ? url/s]
# Dl Size...:  96%|#########################8 | 314/328 [01:43<00:07,  1.80 MiB/s]
#
# Extraction completed...: 0 file [01:43, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:44<?, ? url/s]
# Dl Size...:  96%|#########################9 | 315/328 [01:44<00:06,  1.90 MiB/s]
#
# Extraction completed...: 0 file [01:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:44<?, ? url/s]
# Dl Size...:  96%|########################## | 316/328 [01:44<00:06,  1.96 MiB/s]
#
# Extraction completed...: 0 file [01:44, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:45<?, ? url/s]
# Dl Size...:  97%|########################## | 317/328 [01:45<00:05,  2.05 MiB/s]
#
# Extraction completed...: 0 file [01:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:45<?, ? url/s]
# Dl Size...:  97%|##########################1| 318/328 [01:45<00:05,  2.00 MiB/s]
#
# Extraction completed...: 0 file [01:45, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:46<?, ? url/s]
# Dl Size...:  97%|##########################2| 319/328 [01:46<00:04,  2.05 MiB/s]
# Extraction completed...: 0 file [01:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:46<?, ? url/s]
# Dl Size...:  98%|##########################3| 320/328 [01:46<00:03,  2.17 MiB/s]
#
# Extraction completed...: 0 file [01:46, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:47<?, ? url/s]
# Dl Size...:  98%|##########################4| 321/328 [01:47<00:03,  2.01 MiB/s]
#
# Extraction completed...: 0 file [01:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:47<?, ? url/s]
# Dl Size...:  98%|##########################5| 322/328 [01:47<00:03,  1.73 MiB/s]
#
# Extraction completed...: 0 file [01:47, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:48<?, ? url/s]
# Dl Size...:  98%|##########################5| 323/328 [01:48<00:03,  1.65 MiB/s]
#
# Extraction completed...: 0 file [01:48, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:50<?, ? url/s]
# Dl Size...:  99%|##########################6| 324/328 [01:50<00:03,  1.16 MiB/s]
#
# Extraction completed...: 0 file [01:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:50<?, ? url/s]
# Dl Size...:  99%|##########################7| 325/328 [01:50<00:02,  1.34 MiB/s]
#
# Extraction completed...: 0 file [01:50, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:51<?, ? url/s]
# Dl Size...:  99%|##########################8| 326/328 [01:51<00:01,  1.44 MiB/s]
#
# Extraction completed...: 0 file [01:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:51<?, ? url/s]
# Dl Size...: 100%|##########################9| 327/328 [01:51<00:00,  1.65 MiB/s]
#
# Extraction completed...: 0 file [01:51, ? file/s]
# Dl Completed...:   0%|                                  | 0/1 [01:51<?, ? url/s]
# Dl Size...: 100%|###########################| 328/328 [01:51<00:00,  1.81 MiB/s]
#
# Dl Completed...: 100%|#########################| 1/1 [01:52<00:00, 112.27s/ url]
# Dl Size...: 100%|###########################| 328/328 [01:52<00:00,  1.81 MiB/s]
#
# Dl Completed...: 100%|#########################| 1/1 [01:52<00:00, 112.27s/ url]
# Dl Size...: 100%|###########################| 328/328 [01:52<00:00,  1.81 MiB/s]
#
# Extraction completed...:   0%|                         | 0/1 [01:52<?, ? file/s]
#
# Dl Completed...: 100%|#########################| 1/1 [01:59<00:00, 112.27s/ url]
# Dl Size...: 100%|###########################| 328/328 [01:59<00:00,  1.81 MiB/s]
#
# Extraction completed...: 100%|################| 1/1 [01:59<00:00, 119.24s/ file]
# Extraction completed...: 100%|################| 1/1 [01:59<00:00, 119.24s/ file]
#
# Dl Size...: 100%|###########################| 328/328 [01:59<00:00,  2.75 MiB/s]
#
# Dl Completed...: 100%|#########################| 1/1 [01:59<00:00, 119.24s/ url]
# I0604 17:50:10.960788 4621145536 dataset_builder.py:812] Generating split train
# I0604 17:50:10.962265 4621145536 file_format_adapter.py:233] Writing TFRecords
# Shuffling...:   0%|                                   | 0/1 [00:00<?, ? shard/s]WARNING:tensorflow:From /Users/abdullahmohammed/anaconda3/envs/new/lib/python3.6/site-packages/tensorflow_datasets/core/file_format_adapter.py:209: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# W0604 17:50:11.800405 4621145536 deprecation.py:323] From /Users/abdullahmohammed/anaconda3/envs/new/lib/python3.6/site-packages/tensorflow_datasets/core/file_format_adapter.py:209: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
#
# Reading...: 0 examples [00:00, ? examples/s]
#
# Writing...:   0%|                               | 0/1020 [00:00<?, ? examples/s]
# Writing...:  78%|##############8    | 799/1020 [00:00<00:00, 7978.37 examples/s]
# I0604 17:50:12.021404 4621145536 dataset_builder.py:812] Generating split test
# I0604 17:50:12.021739 4621145536 file_format_adapter.py:233] Writing TFRecords
# Shuffling...:   0%|                                   | 0/1 [00:00<?, ? shard/s]
# Reading...: 0 examples [00:00, ? examples/s]
# Reading...: 964 examples [00:00, 9638.15 examples/s]
# Reading...: 2045 examples [00:00, 9962.05 examples/s]
# Reading...: 3384 examples [00:00, 10790.42 examples/s]
# Reading...: 4633 examples [00:00, 11248.65 examples/s]
# Reading...: 5819 examples [00:00, 11424.28 examples/s]
#
# Writing...:   0%|                               | 0/6149 [00:00<?, ? examples/s]
# Writing...:  16%|###                | 972/6149 [00:00<00:00, 9718.64 examples/s]
# Writing...:  32%|#####6            | 1938/6149 [00:00<00:00, 9700.16 examples/s]
# Writing...:  48%|########6         | 2941/6149 [00:00<00:00, 9795.83 examples/s]
# Writing...:  60%|##########7       | 3675/6149 [00:00<00:00, 8901.37 examples/s]
# Writing...:  72%|############9     | 4430/6149 [00:00<00:00, 8446.73 examples/s]
# Writing...:  86%|###############5  | 5316/6149 [00:00<00:00, 8565.71 examples/s]
# Writing...:  99%|#################7| 6070/6149 [00:00<00:00, 5487.60 examples/s]
# I0604 17:50:19.194127 4621145536 dataset_builder.py:812] Generating split validation
# I0604 17:50:19.194501 4621145536 file_format_adapter.py:233] Writing TFRecords
# Shuffling...:   0%|                                   | 0/1 [00:00<?, ? shard/s]
# Reading...: 0 examples [00:00, ? examples/s]
#
# Writing...:   0%|                               | 0/1020 [00:00<?, ? examples/s]
# Writing...:  95%|##################1| 972/1020 [00:00<00:00, 9717.67 examples/s]
# I0604 17:50:20.514735 4621145536 dataset_builder.py:301] Skipping computing stats for mode ComputeStatsMode.AUTO.
# Dataset oxford_flowers102 downloaded and prepared to /Users/abdullahmohammed/tensorflow_datasets/oxford_flowers102/0.0.1. Subsequent calls will reuse this data.
# name: "oxford_flowers102"
# description: "\nThe Oxford Flowers 102 dataset is a consistent of 102 flower categories commonly occurring\nin the United Kingdom. Each class consists of between 40 and 258 images. The images have\nlarge scale, pose and light variations. In addition, there are categories that have large\nvariations within the category and several very similar categories.\n\nThe dataset is divided into a training set, a validation set and a test set.\nThe training set and validation set each consist of 10 images per class (totalling 1030 images each).\nThe test set consist of the remaining 6129 images (minimum 20 per class).\n"
# citation: "@InProceedings{Nilsback08,\n   author = \"Nilsback, M-E. and Zisserman, A.\",\n   title = \"Automated Flower Classification over a Large Number of Classes\",\n   booktitle = \"Proceedings of the Indian Conference on Computer Vision, Graphics and Image Processing\",\n   year = \"2008\",\n   month = \"Dec\"\n}\n"
# size_in_bytes: 344878000
# location {
#   urls: "https://www.robots.ox.ac.uk/~vgg/data/flowers/102/"
# }
# schema {
#   feature {
#     name: "file_name"
#     type: BYTES
#   }
#   feature {
#     name: "image"
#     type: INT
#     shape {
#       dim {
#         size: -1
#       }
#       dim {
#         size: -1
#       }
#       dim {
#         size: 3
#       }
#     }
#   }
#   feature {
#     name: "label"
#     type: INT
#   }
# }
# splits {
#   name: "test"
#   num_shards: 1
#   statistics {
#     num_examples: 6149
#     features {
#       name: "file_name"
#       type: BYTES
#       bytes_stats {
#         common_stats {
#           num_non_missing: 6149
#         }
#       }
#     }
#     features {
#       name: "image"
#       num_stats {
#         common_stats {
#           num_non_missing: 6149
#         }
#         max: 255.0
#       }
#     }
#     features {
#       name: "label"
#       num_stats {
#         common_stats {
#           num_non_missing: 6149
#         }
#         max: 101.0
#       }
#     }
#   }
# }
# splits {
#   name: "train"
#   num_shards: 1
#   statistics {
#     num_examples: 1020
#     features {
#       name: "file_name"
#       type: BYTES
#       bytes_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#       }
#     }
#     features {
#       name: "image"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 255.0
#       }
#     }
#     features {
#       name: "label"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 101.0
#       }
#     }
#   }
# }
# splits {
#   name: "validation"
#   num_shards: 1
#   statistics {
#     num_examples: 1020
#     features {
#       name: "file_name"
#       type: BYTES
#       bytes_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#       }
#     }
#     features {
#       name: "image"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 255.0
#       }
#     }
#     features {
#       name: "label"
#       num_stats {
#         common_stats {
#           num_non_missing: 1020
#         }
#         max: 101.0
#       }
#     }
#   }
# }
# supervised_keys {
#   input: "image"
#   output: "label"
# }
# version: "0.0.1"
# WARNING:absl:Found a different version 2.1.1 of dataset oxford_flowers102 in data_dir /Users/abdullahmohammed/tensorflow_datasets. Using currently defined version 0.0.1.
# WARNING:absl:Warning: Setting shuffle_files=True because split=TRAIN and shuffle_files=None. This behavior will be deprecated on 2019-08-06, at which point shuffle_files=False will be the default for all splits.

# %% [markdown]
# ## Explore the Dataset

# %%
# database informition 
dataset_info
# Out:
# tfds.core.DatasetInfo(
#     name='oxford_flowers102',
#     version=0.0.1,
#     description='
# The Oxford Flowers 102 dataset is a consistent of 102 flower categories commonly occurring
# in the United Kingdom. Each class consists of between 40 and 258 images. The images have
# large scale, pose and light variations. In addition, there are categories that have large
# variations within the category and several very similar categories.
#
# The dataset is divided into a training set, a validation set and a test set.
# The training set and validation set each consist of 10 images per class (totalling 1030 images each).
# The test set consist of the remaining 6129 images (minimum 20 per class).
# ',
#     urls=['https://www.robots.ox.ac.uk/~vgg/data/flowers/102/'],
#     features=FeaturesDict({
#         'file_name': Text(shape=(), dtype=tf.string),
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=102),
#     }),
#     total_num_examples=8189,
#     splits={
#         'test': 6149,
#         'train': 1020,
#         'validation': 1020,
#     },
#     supervised_keys=('image', 'label'),
#     citation="""@InProceedings{Nilsback08,
#        author = "Nilsback, M-E. and Zisserman, A.",
#        title = "Automated Flower Classification over a Large Number of Classes",
#        booktitle = "Proceedings of the Indian Conference on Computer Vision, Graphics and Image Processing",
#        year = "2008",
#        month = "Dec"
#     }""",
#     redistribution_info=,
# )

# %%
# TODO: Print the shape and corresponding label of 3 images in the training set.
for image, label in training_set.take(3):
    print('Shape is',image.shape,'Label is' ,label.numpy())
# Out:
# Shape is (500, 666, 3) Label is 52
# Shape is (752, 500, 3) Label is 60
# Shape is (500, 694, 3) Label is 52

# %%
# TODO: Get the number of examples in each set from the dataset info.
info = dataset_info
train_egs = info.splits['train'].num_examples
test_egs = info.splits['test'].num_examples
val_egs = info.splits['validation'].num_examples
# print(train_egs, test_egs, val_egs)
print("There are {} images in the training set".format(train_egs))
print("There are {} images in the validation set".format(val_egs))
print('There are {} images in the test set'.format(test_egs))
# TODO: Get the number of classes in the dataset from the dataset info.
num_classes = info.features['label'].num_classes
# print(num_classes)
print('There are {} classes in our dataset'.format(num_classes))
# Out:
# There are 1020 images in the training set
# There are 1020 images in the validation set
# There are 6149 images in the test set
# There are 102 classes in our dataset

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding image label. 
for image,label in training_set.take(1):
    plt.imshow(image.numpy())
    plt.title('Label is=%i' % label.numpy() , color="r" )

# %% [markdown]
# ### Label Mapping
#
# You'll also need to load in a mapping from label to category name. You can find this in the file `label_map.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/3.7/library/json.html). This will give you a dictionary mapping the integer coded labels to the actual names of the flowers.

# %%
# checking the minimum and maximum label value in the "train_set"
minx = 1000
maxx = -1
for image,label in training_set.take(1000):
    minx = min(label.numpy(), minx)
    maxx = max(label.numpy(), maxx)
minx, maxx
# Out:
# (0, 101)

# %%
# checking the minimum and maximum label value in the "test_set"
minx = 1000
maxx = -1
for image,label in test_set.take(1000):
    minx = min(label.numpy(), minx)
    maxx = max(label.numpy(), maxx)
minx, maxx
# Out:
# (0, 101)

# %%
# checking the minimum and maximum label value in the "val_set"
minx = 1000
maxx = -1
for image,label in validation_set.take(1000):
    minx = min(label.numpy(), minx)
    maxx = max(label.numpy(), maxx)
minx, maxx
# Out:
# (0, 101)

# %% [markdown]
# ### Reading the class names from the json file

# %%
# if you have label_map.json 
#with open('label_map.json', 'r') as f:
   # class_names = json.load(f)

# %%
# If you dont use the URL 
file_location='https://github.com/CheloGE/ML-tensorflow-Image_classifier-oxford_flowers102/blob/master/label_map.json?raw=1'
r = requests.get(file_location, stream=True)
class_names=json.loads(r.content.decode('utf-8'))
#print(class_names)

# %%
## Class names contain index from 1 to 102, 
#whereas the datasets have label indices from 0 to 101, hence remapping
class_names_new = dict()
for key in class_names:
    class_names_new[str(int(key)-1)] = class_names[key]

# %%
print(class_names_new)
# Out:
# {'20': 'fire lily', '2': 'canterbury bells', '44': 'bolero deep blue', '0': 'pink primrose', '33': 'mexican aster', '26': 'prince of wales feathers', '6': 'moon orchid', '15': 'globe-flower', '24': 'grape hyacinth', '25': 'corn poppy', '78': 'toad lily', '38': 'siam tulip', '23': 'red ginger', '66': 'spring crocus', '34': 'alpine sea holly', '31': 'garden phlox', '9': 'globe thistle', '5': 'tiger lily', '92': 'ball moss', '32': 'love in the mist', '8': 'monkshood', '101': 'blackberry lily', '13': 'spear thistle', '18': 'balloon flower', '99': 'blanket flower', '12': 'king protea', '48': 'oxeye daisy', '14': 'yellow iris', '60': 'cautleya spicata', '30': 'carnation', '63': 'silverbush', '67': 'bearded iris', '62': 'black-eyed susan', '68': 'windflower', '61': 'japanese anemone', '19': 'giant white arum lily', '37': 'great masterwort', '3': 'sweet pea', '85': 'tree mallow', '100': 'trumpet creeper', '41': 'daffodil', '21': 'pincushion flower', '1': 'hard-leaved pocket orchid', '53': 'sunflower', '65': 'osteospermum', '69': 'tree poppy', '84': 'desert-rose', '98': 'bromelia', '86': 'magnolia', '4': 'english marigold', '91': 'bee balm', '27': 'stemless gentian', '96': 'mallow', '56': 'gaura', '39': 'lenten rose', '46': 'marigold', '58': 'orange dahlia', '47': 'buttercup', '54': 'pelargonium', '35': 'ruby-lipped cattleya', '90': 'hippeastrum', '28': 'artichoke', '70': 'gazania', '89': 'canna lily', '17': 'peruvian lily', '97': 'mexican petunia', '7': 'bird of paradise', '29': 'sweet william', '16': 'purple coneflower', '51': 'wild pansy', '83': 'columbine', '11': "colt's foot", '10': 'snapdragon', '95': 'camellia', '22': 'fritillary', '49': 'common dandelion', '43': 'poinsettia', '52': 'primula', '71': 'azalea', '64': 'californian poppy', '79': 'anthurium', '75': 'morning glory', '36': 'cape flower', '55': 'bishop of llandaff', '59': 'pink-yellow dahlia', '81': 'clematis', '57': 'geranium', '74': 'thorn apple', '40': 'barbeton daisy', '94': 'bougainvillea', '42': 'sword lily', '82': 'hibiscus', '77': 'lotus lotus', '87': 'cyclamen', '93': 'foxglove', '80': 'frangipani', '73': 'rose', '88': 'watercress', '72': 'water lily', '45': 'wallflower', '76': 'passion flower', '50': 'petunia'}

# %%
len(class_names_new.keys())
# Out:
# 102

# %%
len(class_names_new.keys())
# Out:
# 102

# %%
print(class_names)
# Out:
# {'21': 'fire lily', '3': 'canterbury bells', '45': 'bolero deep blue', '1': 'pink primrose', '34': 'mexican aster', '27': 'prince of wales feathers', '7': 'moon orchid', '16': 'globe-flower', '25': 'grape hyacinth', '26': 'corn poppy', '79': 'toad lily', '39': 'siam tulip', '24': 'red ginger', '67': 'spring crocus', '35': 'alpine sea holly', '32': 'garden phlox', '10': 'globe thistle', '6': 'tiger lily', '93': 'ball moss', '33': 'love in the mist', '9': 'monkshood', '102': 'blackberry lily', '14': 'spear thistle', '19': 'balloon flower', '100': 'blanket flower', '13': 'king protea', '49': 'oxeye daisy', '15': 'yellow iris', '61': 'cautleya spicata', '31': 'carnation', '64': 'silverbush', '68': 'bearded iris', '63': 'black-eyed susan', '69': 'windflower', '62': 'japanese anemone', '20': 'giant white arum lily', '38': 'great masterwort', '4': 'sweet pea', '86': 'tree mallow', '101': 'trumpet creeper', '42': 'daffodil', '22': 'pincushion flower', '2': 'hard-leaved pocket orchid', '54': 'sunflower', '66': 'osteospermum', '70': 'tree poppy', '85': 'desert-rose', '99': 'bromelia', '87': 'magnolia', '5': 'english marigold', '92': 'bee balm', '28': 'stemless gentian', '97': 'mallow', '57': 'gaura', '40': 'lenten rose', '47': 'marigold', '59': 'orange dahlia', '48': 'buttercup', '55': 'pelargonium', '36': 'ruby-lipped cattleya', '91': 'hippeastrum', '29': 'artichoke', '71': 'gazania', '90': 'canna lily', '18': 'peruvian lily', '98': 'mexican petunia', '8': 'bird of paradise', '30': 'sweet william', '17': 'purple coneflower', '52': 'wild pansy', '84': 'columbine', '12': "colt's foot", '11': 'snapdragon', '96': 'camellia', '23': 'fritillary', '50': 'common dandelion', '44': 'poinsettia', '53': 'primula', '72': 'azalea', '65': 'californian poppy', '80': 'anthurium', '76': 'morning glory', '37': 'cape flower', '56': 'bishop of llandaff', '60': 'pink-yellow dahlia', '82': 'clematis', '58': 'geranium', '75': 'thorn apple', '41': 'barbeton daisy', '95': 'bougainvillea', '43': 'sword lily', '83': 'hibiscus', '78': 'lotus lotus', '88': 'cyclamen', '94': 'foxglove', '81': 'frangipani', '74': 'rose', '89': 'watercress', '73': 'water lily', '46': 'wallflower', '77': 'passion flower', '51': 'petunia'}

# %%
del class_names

# %%
# TODO: Plot 1 image from the training set. Set the title 
# of the plot to the corresponding class name. 
# TODO: Plot 1 image from the training set. Set the title 

for image,label in training_set.take(1):
    plt.imshow(image.numpy())
    plt.title(class_names_new[str(label.numpy())] , color= 'r')

# %% [markdown]
# ## Create Pipeline

# %% [markdown]
# # Build and Train the Classifier
#
# Now that the data is ready, it's time to build and train the classifier. You should use the MobileNet pre-trained model from TensorFlow Hub to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. If you want to talk through it with someone, chat with your fellow students!
#
# Refer to the rubric for guidance on successfully completing this section. Things you'll need to do:
#
# * Load the MobileNet pre-trained network from TensorFlow Hub.
# * Define a new, untrained feed-forward network as a classifier.
# * Train the classifier.
# * Plot the loss and accuracy values achieved during training for the training and validation set.
# * Save your trained model as a Keras model.
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right.
#
# **Note for Workspace users:** One important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module. Also, If your model is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network.
IMG_SIZE = 224
IMG_SHAPE = (IMG_SIZE, IMG_SIZE, 3)
BATCH_SIZE=64

# %%
def format_image(image, label):
    image = tf.cast(image, tf.float32)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image /= 255
    return image, label

# %% [markdown]
# #### The pipeline for each set that returns batches of images, with all the transformations :

# %%
training_batch = training_set.shuffle(buffer_size = 10 * BATCH_SIZE).map(format_image).batch(BATCH_SIZE).prefetch(1)
validation_batch = validation_set.map(format_image).batch(BATCH_SIZE).prefetch(1)
test_batch = test_set.map(format_image).batch(BATCH_SIZE).prefetch(1)

# %%
URL = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"

feature_extractor = hub.KerasLayer(URL, input_shape=(IMG_SHAPE))
feature_extractor.trainable = False

# %%
    model = tf.keras.Sequential([feature_extractor,
                                 tf.keras.layers.Dense(600,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(300,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(num_classes, activation='softmax')
                                ])

    print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 600)               768600
# _________________________________________________________________
# dropout (Dropout)            (None, 600)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               180300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 102)               30702
# =================================================================
# Total params: 3,237,586
# Trainable params: 979,602
# Non-trainable params: 2,257,984
# _________________________________________________________________
# None

# %%
# earlystop function 
earlystop_callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',
                          min_delta = 0.0001,
                          patience = 3,
                          verbose = 1,
                          restore_best_weights = True)

# %%
# checkpoint function for save best accuracy automatic
checkpoint_filepath = './flower.h5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    save_best_only=True)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
EPOCHS = 30
history = model.fit(training_batch,
                    epochs=EPOCHS,
                    validation_data=validation_batch,
                    callbacks=[model_checkpoint_callback , earlystop_callback])
# Out:
# Epoch 1/30
# 16/16 [==============================] - 39s 2s/step - loss: 4.5254 - accuracy: 0.0392 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 16/16 [==============================] - 33s 2s/step - loss: 3.3217 - accuracy: 0.3078 - val_loss: 2.4938 - val_accuracy: 0.5069
# Epoch 3/30
# 16/16 [==============================] - 33s 2s/step - loss: 1.9389 - accuracy: 0.5667 - val_loss: 1.6405 - val_accuracy: 0.6343
# Epoch 4/30
# 16/16 [==============================] - 33s 2s/step - loss: 1.1472 - accuracy: 0.7186 - val_loss: 1.2956 - val_accuracy: 0.6922
# Epoch 5/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.7209 - accuracy: 0.8137 - val_loss: 1.0954 - val_accuracy: 0.7167
# Epoch 6/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.4623 - accuracy: 0.8873 - val_loss: 0.9784 - val_accuracy: 0.7333
# Epoch 7/30
# 16/16 [==============================] - 32s 2s/step - loss: 0.3145 - accuracy: 0.9275 - val_loss: 0.9322 - val_accuracy: 0.7520
# Epoch 8/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.2440 - accuracy: 0.9539 - val_loss: 0.8520 - val_accuracy: 0.7794
# Epoch 9/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.1883 - accuracy: 0.9569 - val_loss: 0.8152 - val_accuracy: 0.7922
# Epoch 10/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.1345 - accuracy: 0.9755 - val_loss: 0.7924 - val_accuracy: 0.7961
# Epoch 11/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.1022 - accuracy: 0.9833 - val_loss: 0.7961 - val_accuracy: 0.7931
# Epoch 12/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.0665 - accuracy: 0.9961 - val_loss: 0.7568 - val_accuracy: 0.8010
# Epoch 13/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.0679 - accuracy: 0.9922 - val_loss: 0.7623 - val_accuracy: 0.8049
# Epoch 14/30
# 16/16 [==============================] - 32s 2s/step - loss: 0.0455 - accuracy: 0.9961 - val_loss: 0.7251 - val_accuracy: 0.8225
# Epoch 15/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.0510 - accuracy: 0.9941 - val_loss: 0.7522 - val_accuracy: 0.8010
# Epoch 16/30
# 16/16 [==============================] - 33s 2s/step - loss: 0.0423 - accuracy: 0.9951 - val_loss: 0.7473 - val_accuracy: 0.8108
# Epoch 17/30
# 15/16 [===========================>..] - ETA: 1s - loss: 0.0430 - accuracy: 0.9958Restoring model weights from the end of the best epoch.
# 16/16 [==============================] - 34s 2s/step - loss: 0.0430 - accuracy: 0.9961 - val_loss: 0.7479 - val_accuracy: 0.8049
# Epoch 00017: early stopping

# %%
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
# TODO: Plot the loss and accuracy values achieved during training for the training and validation set.
print(history.history.keys())

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Testing your Network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# TODO: Print the loss and accuracy values achieved on the entire test set.
model.evaluate(test_batch)
# Out:
# 97/97 [==============================] - 94s 969ms/step - loss: 0.9138 - accuracy: 0.7653
# [0.9138136813321065, 0.7653277]

# %% [markdown]
# ## Save the Model
#
# Now that your network is trained, save the model so you can load it later for making inference. In the cell below save your model as a Keras model (*i.e.* save it as an HDF5 file).

# %%
# TODO: Save your trained model as a Keras model.

#save it througt checkpoint above 

#if you dont want use checkpoint function use this codes below 
path='./flower.h5'
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
model.save_weights(path)

# %% [markdown]
# ## Load the Keras Model
#
# Load the Keras model you saved above.

# %%
# TODO: Load the Keras model
model.load_weights(checkpoint_filepath)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              2257984
# _________________________________________________________________
# dense (Dense)                (None, 600)               768600
# _________________________________________________________________
# dropout (Dropout)            (None, 600)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 300)               180300
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 102)               30702
# =================================================================
# Total params: 3,237,586
# Trainable params: 979,602
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %% [markdown]
# # Inference for Classification
#
# Now you'll write a function that uses your trained network for inference. Write a function called `predict` that takes an image, a model, and then returns the top $K$ most likely class labels along with the probabilities. The function call should look like:
#
# ```python
# probs, classes = predict(image_path, model, top_k)
# ```
#
# If `top_k=5` the output of the `predict` function should be something like this:
#
# ```python
# probs, classes = predict(image_path, model, 5)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# Your `predict` function should use `PIL` to load the image from the given `image_path`. You can use the [Image.open](https://pillow.readthedocs.io/en/latest/reference/Image.html#PIL.Image.open) function to load the images. The `Image.open()` function returns an `Image` object. You can convert this `Image` object to a NumPy array by using the `np.asarray()` function.
#
# The `predict` function will also need to handle pre-processing the input image such that it can be used by your model. We recommend you write a separate function called `process_image` that performs the pre-processing. You can then call the `process_image` function from the `predict` function.
#
# ### Image Pre-processing
#
# The `process_image` function should take in an image (in the form of a NumPy array) and return an image in the form of a NumPy array with shape `(224, 224, 3)`.
#
# First, you should convert your image into a TensorFlow Tensor and then resize it to the appropriate size using `tf.image.resize`.
#
# Second, the pixel values of the input images are typically encoded as integers in the range 0-255, but the model expects the pixel values to be floats in the range 0-1. Therefore, you'll also need to normalize the pixel values.
#
# Finally, convert your image back to a NumPy array using the `.numpy()` method.

# %%
# TODO: Create the process_image function
def process_image(image):
    image=tf.convert_to_tensor(image,tf.float32)
    image=tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image/=255
    return image

# %%
from PIL import Image

image_path = './test_images/hard-leaved_pocket_orchid.jpg'
im = Image.open(image_path)
test_image = np.asarray(im)

processed_test_image = process_image(test_image)

fig, (ax1, ax2) = plt.subplots(figsize=(10,10), ncols=2)
ax1.imshow(test_image)
ax1.set_title('Original Image')
ax2.imshow(processed_test_image)
ax2.set_title('Processed Image')
plt.tight_layout()
plt.show()

# %%
# TODO: Create the predict function
def predict(image_path=None, model=None, top_k=None):
    im = Image.open(image_path)
    test_image = np.asarray(im)
    processed_test_image = process_image(test_image)    
    #print(image_path.split("/")[-1])
    #plt.imshow(processed_test_image)
    processed_test_image=np.expand_dims(processed_test_image,0)
    probs=model.predict(processed_test_image)
    return tf.nn.top_k(probs, k=top_k)

# %%
def filtered(classes):
    return [class_names_new.get(str(key)) if key else "Placeholder" for key in classes.numpy().squeeze().tolist()]

# %%
def prediction_result(filename):
    probs, classes = predict(image_path=filename, model=model, top_k=5)
    print(f"\u2022 File: {filename} \n\u2022 Probability: {probs[0]}\n\u2022 Classes: {classes}")

    im = Image.open(filename)
    test_image = np.asarray(im)
    axis_label=filtered(classes)
    fig,(ax1,ax2)=plt.subplots(figsize=(10,3),ncols=2)
    ax1.imshow(test_image,cmap=plt.cm.binary)
    ax2.set_title('Class Probability')
    ax2.barh(np.array(axis_label),probs[0])

# %% [markdown]
# # Sanity Check
#
# It's always good to check the predictions made by your model to make sure they are correct. To check your predictions we have provided 4 images in the `./test_images/` folder:
#
# * cautleya_spicata.jpg
# * hard-leaved_pocket_orchid.jpg
# * orange_dahlia.jpg
# * wild_pansy.jpg
#
# In the cell below use `matplotlib` to plot the input image alongside the probabilities for the top 5 classes predicted by your model. Plot the probabilities as a bar graph. The plot should look like this:
#
# <img src='assets/inference_example.png' width=600px>
#
# You can convert from the class integer labels to actual flower names using `class_names`.

# %%
filenames=[ './test_images/cautleya_spicata.jpg', 
           './test_images/hard-leaved_pocket_orchid.jpg',
           './test_images/orange_dahlia.jpg',
           './test_images/wild_pansy.jpg']

# %%
# TODO: Plot the input image along with the top 5 classes
x = range(4)
for n in x:
    prediction_result(filenames[n])
# Out:
# • File: ./test_images/cautleya_spicata.jpg
# • Probability: [0.85888106 0.11780059 0.00948624 0.00741534 0.00343509]
# • Classes: [[60 23 45 14 10]]
# • File: ./test_images/hard-leaved_pocket_orchid.jpg
# • Probability: [9.9995339e-01 1.1689261e-05 8.4223011e-06 6.4458563e-06 2.7228039e-06]
# • Classes: [[ 1 79 76 66 67]]
# • File: ./test_images/orange_dahlia.jpg
# • Probability: [0.6117803  0.30621955 0.04970106 0.01349318 0.00430663]
# • Classes: [[ 4 58 65 40 62]]
# • File: ./test_images/wild_pansy.jpg
# • Probability: [9.9994850e-01 1.4146743e-05 9.0662279e-06 3.8373341e-06 3.4928896e-06]
# • Classes: [[51 18 68 80 81]]
